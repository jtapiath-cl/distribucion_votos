# %%
pwd
# Out:
# '/mnt/c/Users/javie/Documents/Projects/Analytics/20191119-votaciones_diputados'

# %%
# %ls
# Out:
#  20191119-votacion_viaticos.xlsx*  '~$20191119-votacion_viaticos.xlsx'*
#  20191125-vote_checker.ipynb*

# %%
import os
import subprocess
import pandas as pd
import numpy as np

# %%
votacion_datos = pd.read_excel("20191119-votacion_viaticos.xlsx", sheet_name = 1)

# %%
votacion_datos
# Out:
#                              Nombre  \
# 0           Alarcón Rojas, Florcita
# 1         Alessandri Vergara, Jorge
# 2               Alinco Bustos, René
# 3        Álvarez Ramírez, Sebastián
# 4               Álvarez Vera, Jenny
# ..                              ...
# 150              Vidal Rojas, Pablo
# 151  Von Mühlenbrock Zamora, Gastón
# 152           Walker Prieto, Matías
# 153      Winter Etcheberry, Gonzalo
# 154             Yeomans Araya, Gael
#
#                                                 Región Distrito  \
# 0                                     VII de del Maule     N°17
# 1                      RM de Metropolitana de Santiago     N°10
# 2    XI de de Aysén del General Carlos Ibáñez del C...     N°27
# 3                                IX de de La Araucanía     N°23
# 4                                    X de de Los Lagos     N°26
# ..                                                 ...      ...
# 150                    RM de Metropolitana de Santiago      N°8
# ...

# %%
for key, group in votacion_datos.groupby(["Partido"]):
    print(key)
    print(group)
# Out:
# Evolución Política
#                            Nombre                           Región Distrito  \
# 3      Álvarez Ramírez, Sebastián            IX de de La Araucanía     N°23
# 32    Cruz-Coke Carvallo, Luciano  RM de Metropolitana de Santiago     N°10
# 65         Kast Sommerhoff, Pablo               V de de Valparaíso      N°6
# 66      Keitel Bianchi, Sebastián  RM de Metropolitana de Santiago      N°9
# 85         Molina Magofke, Andrés            IX de de La Araucanía     N°23
# 140  Undurraga Gazitúa, Francisco  RM de Metropolitana de Santiago     N°11
#
#                 Partido                           Correo
# 3    Evolución Política    sebastian.alvarez@congreso.cl
# 32   Evolución Política    luciano.cruz-coke@congreso.cl
# 65   Evolución Política           pablo.kast@congreso.cl
# 66   Evolución Política     sebastian.keitel@congreso.cl
# 85   Evolución Política        andres.molina@congreso.cl
# 140  Evolución Política  francisco.undurraga@congreso.cl
# ...
